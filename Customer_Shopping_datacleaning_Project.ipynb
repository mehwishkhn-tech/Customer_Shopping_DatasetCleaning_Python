# %%
# PROJECT: Customer Shopping Analysis
# Data Cleaning
# TOOL: Python (Pandas)
# AUTHOR: Mehwish Nisha Khan

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas numpy matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %%
df = pd.read_csv(r"C:\Users\mehwi\OneDrive\Documents\customer_shopping_data1.csv")
print("Dataset loaded!")
print(df.shape)
# Out:
# Dataset loaded!
# (99457, 10)

# %%
df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card   05-08-2022          Kanyon
# 1     Debit Card   12-12-2021  Forum Istanbul
# 2           Cash   09-11-2021       Metrocity
# 3    Credit Card   16-05-2021    Metropol AVM
# 4           Cash   24-10-2021          Kanyon

# %%
df.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321
# std       14.990054      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  str
#  1   customer_id     99457 non-null  str
#  2   gender          99457 non-null  str
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  str
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  str
#  8   invoice_date    99457 non-null  str
#  9   shopping_mall   99457 non-null  str
# dtypes: float64(1), int64(2), str(7)
# memory usage: 7.6 MB

# %%
df.isnull().sum()
#data was already cleaned no missing values
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %%
df.dtypes
# Out:
# invoice_no            str
# customer_id           str
# gender                str
# age                 int64
# category              str
# quantity            int64
# price             float64
# payment_method        str
# invoice_date          str
# shopping_mall         str
# dtype: object

# %%
df['total_amount']=df['quantity']*df['price']
print("Total amount column created")
df.head()
# Out:
# Total amount column created
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall  total_amount
# 0    Credit Card   05-08-2022          Kanyon       7502.00
# 1     Debit Card   12-12-2021  Forum Istanbul       5401.53
# 2           Cash   09-11-2021       Metrocity        300.08
# 3    Credit Card   16-05-2021    Metropol AVM      15004.25
# 4           Cash   24-10-2021          Kanyon        242.40

# %%
print("duplicate rows:",df.duplicated().sum())
# Out:
# duplicate rows: 0

# %%
df=df.drop_duplicates()
print("clean dataset shapes:",df.shape)
# Out:
# clean dataset shapes: (99457, 11)

# %%
df.columns=df.columns.str.strip().str.lower().str.replace(' ','_')
print("columns names renamed")
# Out:
# columns names renamed

# %%
df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall  total_amount
# 0    Credit Card   05-08-2022          Kanyon       7502.00
# 1     Debit Card   12-12-2021  Forum Istanbul       5401.53
# 2           Cash   09-11-2021       Metrocity        300.08
# 3    Credit Card   16-05-2021    Metropol AVM      15004.25
# 4           Cash   24-10-2021          Kanyon        242.40

# %%
print(df['category'].value_counts())
# Out:
# category
# Clothing           34487
# Cosmetics          15097
# Food & Beverage    14776
# Toys               10087
# Shoes              10034
# Souvenir            4999
# Technology          4996
# Books               4981
# Name: count, dtype: int64

# %%
print(df['payment_method'].value_counts())
# Out:
# payment_method
# Cash           44447
# Credit Card    34931
# Debit Card     20079
# Name: count, dtype: int64

# %%
print(df['gender'].value_counts())
# Out:
# gender
# Female    59482
# Male      39975
# Name: count, dtype: int64

# %%
print(df.groupby('category')['gender'].value_counts())
# Out:
# category         gender
# Books            Female     2906
#                  Male       2075
# Clothing         Female    20652
#                  Male      13835
# Cosmetics        Female     9070
#                  Male       6027
# Food & Beverage  Female     8804
#                  Male       5972
# Shoes            Female     5967
#                  Male       4067
# Souvenir         Female     3017
#                  Male       1982
# Technology       Female     2981
#                  Male       2015
# Toys             Female     6085
#                  Male       4002
# Name: count, dtype: int64

# %%
print(df.groupby(['category','gender']).size().unstack())
# Out:
# gender           Female   Male
# category
# Books              2906   2075
# Clothing          20652  13835
# Cosmetics          9070   6027
# Food & Beverage    8804   5972
# Shoes              5967   4067
# Souvenir           3017   1982
# Technology         2981   2015
# Toys               6085   4002

# %%
df.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall',
#        'total_amount'],
#       dtype='str')

# %%
bins=[0,19,25,40,58,80]
labels=['Young','Young Adult','Adult','Middle Aged','Senior']
df['age_group']= pd.cut(df['age']
                        , bins=bins, labels=labels)

# %%
df[['age','age_group']].head(10)
# Out:
#    age    age_group
# 0   28        Adult
# 1   21  Young Adult
# 2   20  Young Adult
# 3   66       Senior
# 4   53  Middle Aged
# 5   28        Adult
# 6   49  Middle Aged
# 7   32        Adult
# 8   69       Senior
# 9   60       Senior

# %%
print(df['shopping_mall'].value_counts())
# Out:
# shopping_mall
# Mall of Istanbul     19943
# Kanyon               19823
# Metrocity            15011
# Metropol AVM         10161
# Istinye Park          9781
# Zorlu Center          5075
# Cevahir AVM           4991
# Forum Istanbul        4947
# Viaport Outlet        4914
# Emaar Square Mall     4811
# Name: count, dtype: int64

# %%
print("Youngest customer:",df['age'].min())
print("Eldest customer:",df['age'].max())
# Out:
# Youngest customer: 18
# Eldest customer: 69

# %%
df['price'] = df['price'].round(2)
print(df['price'].head())
# Out:
# 0    1500.40
# 1    1800.51
# 2     300.08
# 3    3000.85
# 4      60.60
# Name: price, dtype: float64

# %%
df['total_amount'] = df['total_amount'].round(2)
print(df['total_amount'].head())
# Out:
# 0     7502.00
# 1     5401.53
# 2      300.08
# 3    15004.25
# 4      242.40
# Name: total_amount, dtype: float64

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    -------------- ------------------------- 1.0/2.8 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 9.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 10.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [psycopg2-binary]
#    ---------------------------------------- 0/3 [psycopg2-binary]
#    ---------------------------------------- 0/3 [psycopg2-binary]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
# ...

# %%
from sqlalchemy import create_engine

# Connection details
username = "postgres"
password = "mehwishserver0616"
host = "localhost"
port = "5432"
database = "Customer_Shopping_Analysis_SQL"

# Create connection
engine = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{database}')

# Upload dataframe to PostgreSQL with table name "customers"
df.to_sql('customers', engine, if_exists='replace', index=False)

print("Data uploaded to PostgreSQL successfully!")
print("Table name: customers")
# Out:
# Data uploaded to PostgreSQL successfully!
# Table name: customers

# %%
df.head(10)
# Out:
#   invoice_no customer_id  gender  age   category  quantity    price  \
# 0    I138884     C241288  Female   28   Clothing         5  1500.40
# 1    I317333     C111565    Male   21      Shoes         3  1800.51
# 2    I127801     C266599    Male   20   Clothing         1   300.08
# 3    I173702     C988172  Female   66      Shoes         5  3000.85
# 4    I337046     C189076  Female   53      Books         4    60.60
# 5    I227836     C657758  Female   28   Clothing         5  1500.40
# 6    I121056     C151197  Female   49  Cosmetics         1    40.66
# 7    I293112     C176086  Female   32   Clothing         2   600.16
# 8    I293455     C159642    Male   69   Clothing         3   900.24
# 9    I326945     C283361  Female   60   Clothing         2   600.16
#
#   payment_method invoice_date     shopping_mall  total_amount    age_group
# 0    Credit Card   05-08-2022            Kanyon       7502.00        Adult
# ...

# %%
df.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall',
#        'total_amount', 'age_group'],
#       dtype='str')

# %%
df.to_csv(r"C:\Users\mehwi\OneDrive\Documents\customer_shopping_data1.csv",index=False)
print("Clean data exported!")
# Out:
# Clean data exported!
